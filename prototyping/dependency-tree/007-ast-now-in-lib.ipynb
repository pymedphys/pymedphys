# %%
import ast
import pathlib

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pymedphys._experimental import tree

# %%
module_dependencies = tree.get_module_dependencies()

# %%
module_dependencies
